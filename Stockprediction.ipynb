# %% [markdown]
# <a href="https://colab.research.google.com/github/farahhkhalil/Codealpha/blob/main/Stockprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: read the file into df

import pandas as pd
df = pd.read_csv('/content/NLP.csv.ipynb')

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date                                               News  \
# 0           0  2024-03-26  Egypt's bourse fluctuates as Sunday and Monday...
# 1           1  2024-03-06  Egypt's bourse indexes reach record high follo...
# 2           2  2024-02-21  Egyptian Exchange indexes show mixed performan...
# 3           3  2024-02-11  EGX posts collective losses at close of Sunday...
# 4           4  2024-02-07  Egyptian Exchange gains over EGP 23 bln on Wed...
# 5           5  2024-02-01  EGX indices show week of fluctuations amid CBE...
# 6           6  2024-02-01  Market watch: EGX100 exceeds 9,300 Points; gol...
# 7           7  2024-01-31  Marketwatch: EGX indices plunge on Wednesday; ...
# 8           8  2024-01-30  Market watch: EGX30 surpasses 30,000 points on...
# 9           9  2024-01-28  Market watch: Egypt's bourse reaches historic ...
#
#                                          Small_Title sentiment
# ...

# %%
df.loc[df['sentiment']== 'neutral']
# Out:
#      Unnamed: 0        Date  \
# 11           11  2024-01-24
# 17           17  2024-01-17
# 20           20  2024-01-14
# 24           24  2024-01-09
# 29           29  2024-01-02
# 32           32  2023-12-28
# 33           33  2023-12-28
# 42           42  2023-12-17
# 58           58  2023-11-29
# 63           63  2023-11-22
# 64           64  2023-11-21
# 65           65  2023-11-21
# 76           76  2023-11-09
# 79           79  2023-11-06
# 84           84  2023-10-31
# 87           87  2023-10-30
# 94           94  2023-10-23
# 110         110  2023-10-03
# 117         117  2023-09-24
# 120         120  2023-09-20
# 122         122  2023-09-18
# 137         137  2023-08-31
# 143         143  2023-08-24
# 159         159  2023-07-26
# 160         160  2023-07-25
# 172         172  2023-06-26
# 187         187  2023-06-06
# 191         191  2023-06-04
# 193         193  2023-06-01
# 196         196  2023-05-28
# 200         200  2023-05-23
# 204         204  2023-05-07
# ...
